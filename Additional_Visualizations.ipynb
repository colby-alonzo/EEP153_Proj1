# %%
# %pip install wbdata
# %pip install plotly

import wbdata
import pandas as pd
import warnings

warnings.filterwarnings("ignore", message="Key .* not in persistent cache")

pd.options.plotting.backend = 'plotly'

import plotly.graph_objects as go
import ipywidgets as widgets
from IPython.display import display
import re

# !pip install cufflinks
import cufflinks as cf
cf.go_offline()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %%
# wbdata.get_topics()

# %%
# wbdata.get_indicators(topic=1)

# %%
# wbdata.get_indicators(topic=6)

# %%
#wbdata.get_indicators(topic=19)

# %%
# Install required libraries
# %pip install wbdata
# %pip install plotly

import wbdata
import pandas as pd
import plotly.express as px
import warnings

warnings.filterwarnings("ignore", message="Key .* not in persistent cache")

pd.options.plotting.backend = 'plotly'

# Define indicator for Terrestrial Protected Areas
indicator = {"ER.LND.PTLD.ZS": "Terrestrial Protected Areas (% of land)"}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicator, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Plot the data
fig = px.line(data, x=data.index, y="Terrestrial Protected Areas (% of land)",
              title="Terrestrial Protected Areas in Brazil Over Time",
              labels={"x": "Year", "y": "Protected Land (%)"})

# Show plot
fig.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicator for Terrestrial Protected Areas
indicator = {"ER.LND.PTLD.ZS": "Terrestrial Protected Areas (% of land)"}

# Define country
country = "PER"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicator, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Plot the data
fig = px.line(data, x=data.index, y="Terrestrial Protected Areas (% of land)",
              title="Terrestrial Protected Areas in Peru Over Time",
              labels={"x": "Year", "y": "Protected Land (%)"})

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-6010173851963993573' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicator for Terrestrial Protected Areas
indicator = {"ER.LND.PTLD.ZS": "Terrestrial Protected Areas (% of land)"}

# Define country
country = "ECU"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicator, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Plot the data
fig = px.line(data, x=data.index, y="Terrestrial Protected Areas (% of land)",
              title="Terrestrial Protected Areas in Ecuador Over Time",
              labels={"x": "Year", "y": "Protected Land (%)"})

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-459185066875222750' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicator for Terrestrial Protected Areas
indicator = {"ER.LND.PTLD.ZS": "Terrestrial Protected Areas (% of land)"}

# Define country
country = "BOL"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicator, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Plot the data
fig = px.line(data, x=data.index, y="Terrestrial Protected Areas (% of land)",
              title="Terrestrial Protected Areas in Bolivia Over Time",
              labels={"x": "Year", "y": "Protected Land (%)"})

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-7751966962743135879' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for Terrestrial Protected Areas and Population
indicators = {
    "ER.LND.PTLD.ZS": "Terrestrial Protected Areas (% of land)",
    "SP.POP.TOTL": "Population"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add Terrestrial Protected Areas trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Terrestrial Protected Areas (% of land)"], 
                         mode="lines", name="Protected Land (%)", 
                         yaxis="y1"))

# Add Population trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Population"], 
                         mode="lines", name="Population", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Terrestrial Protected Areas vs Population in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Terrestrial Protected Areas (% of land)", side="left", showgrid=False),
    yaxis2=dict(title="Population", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-6665069328456725007' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for Terrestrial Protected Areas and Population
indicators = {
    "ER.LND.PTLD.ZS": "Terrestrial Protected Areas (% of land)",
    "SP.POP.TOTL": "Population"
}

# Define country
country = "PER"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add Terrestrial Protected Areas trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Terrestrial Protected Areas (% of land)"], 
                         mode="lines", name="Protected Land (%)", 
                         yaxis="y1"))

# Add Population trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Population"], 
                         mode="lines", name="Population", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Terrestrial Protected Areas vs Population in Peru Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Terrestrial Protected Areas (% of land)", side="left", showgrid=False),
    yaxis2=dict(title="Population", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '909143450263882012' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for Terrestrial Protected Areas and Population
indicators = {
    "ER.LND.PTLD.ZS": "Terrestrial Protected Areas (% of land)",
    "SP.POP.TOTL": "Population"
}

# Define country
country = "ECU"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add Terrestrial Protected Areas trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Terrestrial Protected Areas (% of land)"], 
                         mode="lines", name="Protected Land (%)", 
                         yaxis="y1"))

# Add Population trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Population"], 
                         mode="lines", name="Population", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Terrestrial Protected Areas vs Population in Ecuador Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Terrestrial Protected Areas (% of land)", side="left", showgrid=False),
    yaxis2=dict(title="Population", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '5472610099498213636' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for Terrestrial Protected Areas and Population
indicators = {
    "ER.LND.PTLD.ZS": "Terrestrial Protected Areas (% of land)",
    "SP.POP.TOTL": "Population"
}

# Define country
country = "BOL"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add Terrestrial Protected Areas trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Terrestrial Protected Areas (% of land)"], 
                         mode="lines", name="Protected Land (%)", 
                         yaxis="y1"))

# Add Population trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Population"], 
                         mode="lines", name="Population", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Terrestrial Protected Areas vs Population in Bolivia Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Terrestrial Protected Areas (% of land)", side="left", showgrid=False),
    yaxis2=dict(title="Population", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-2714112449644054089' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for Terrestrial Protected Areas and GDP
indicators = {
    "ER.LND.PTLD.ZS": "Terrestrial Protected Areas (% of land)",
    "NY.GDP.MKTP.CD": "GDP (current US$)"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add Terrestrial Protected Areas trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Terrestrial Protected Areas (% of land)"], 
                         mode="lines", name="Protected Land (%)", 
                         yaxis="y1"))

# Add GDP trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["GDP (current US$)"], 
                         mode="lines", name="GDP (USD)", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Terrestrial Protected Areas vs GDP in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Terrestrial Protected Areas (% of land)", side="left", showgrid=False),
    yaxis2=dict(title="GDP (current US$)", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-4686223257711088507' not in persistent cache.
# ...

# %%
# Define indicators for agricultural greenhouse gas emissions
indicators = {
    "EN.GHG.CO2.AG.MT.CE.AR5": "CO2 Emissions (Mt CO2e)",
    "EN.GHG.CH4.AG.MT.CE.AR5": "CH4 Emissions (Mt CO2e)",
    "EN.GHG.N2O.AG.MT.CE.AR5": "N2O Emissions (Mt CO2e)"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add CO2 emissions trace
fig.add_trace(go.Scatter(x=data.index, y=data["CO2 Emissions (Mt CO2e)"], 
                         mode="lines", name="CO2 Emissions", 
                         line=dict(color='red')))

# Add CH4 emissions trace
fig.add_trace(go.Scatter(x=data.index, y=data["CH4 Emissions (Mt CO2e)"], 
                         mode="lines", name="CH4 Emissions", 
                         line=dict(color='green')))

# Add N2O emissions trace
fig.add_trace(go.Scatter(x=data.index, y=data["N2O Emissions (Mt CO2e)"], 
                         mode="lines", name="N2O Emissions", 
                         line=dict(color='blue')))

# Update layout
fig.update_layout(
    title="Agricultural Greenhouse Gas Emissions in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Emissions (Mt CO2e)"),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '6734487515428026664' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6565107080171792700' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3314367288590550368' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for Agricultural CO2 Emissions and Population
indicators = {
    "EN.GHG.CO2.AG.MT.CE.AR5": "CO2 Emissions from Agriculture (Mt CO2e)",
    "SP.POP.TOTL": "Population"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add CO2 Emissions trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["CO2 Emissions from Agriculture (Mt CO2e)"], 
                         mode="lines", name="CO2 Emissions (Mt CO2e)", 
                         yaxis="y1"))

# Add Population trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Population"], 
                         mode="lines", name="Population", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Agricultural CO2 Emissions vs Population in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="CO2 Emissions from Agriculture (Mt CO2e)", side="left", showgrid=False),
    yaxis2=dict(title="Population", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for Agricultural CH4 Emissions and Population
indicators = {
    "EN.GHG.CH4.AG.MT.CE.AR5": "CH4 Emissions from Agriculture (Mt CO2e)",
    "SP.POP.TOTL": "Population"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add CH4 Emissions trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["CH4 Emissions from Agriculture (Mt CO2e)"], 
                         mode="lines", name="CH4 Emissions (Mt CO2e)", 
                         yaxis="y1"))

# Add Population trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Population"], 
                         mode="lines", name="Population", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Agricultural CH4 Emissions vs Population in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="CH4 Emissions from Agriculture (Mt CO2e)", side="left", showgrid=False),
    yaxis2=dict(title="Population", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for Agricultural N2O Emissions and Population
indicators = {
    "EN.GHG.N2O.AG.MT.CE.AR5": "N2O Emissions from Agriculture (Mt CO2e)",
    "SP.POP.TOTL": "Population"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add N2O Emissions trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["N2O Emissions from Agriculture (Mt CO2e)"], 
                         mode="lines", name="N2O Emissions (Mt CO2e)", 
                         yaxis="y1"))

# Add Population trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Population"], 
                         mode="lines", name="Population", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Agricultural N2O Emissions vs Population in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="N2O Emissions from Agriculture (Mt CO2e)", side="left", showgrid=False),
    yaxis2=dict(title="Population", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for Agricultural CO2 Emissions and Forest Area
indicators = {
    "EN.GHG.CO2.AG.MT.CE.AR5": "CO2 Emissions from Agriculture (Mt CO2e)",
    "AG.LND.FRST.K2": "Forest Area (sq. km)"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add CO2 Emissions trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["CO2 Emissions from Agriculture (Mt CO2e)"], 
                         mode="lines", name="CO2 Emissions (Mt CO2e)", 
                         yaxis="y1"))

# Add Forest Area trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Forest Area (sq. km)"], 
                         mode="lines", name="Forest Area (sq. km)", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Agricultural CO2 Emissions vs Forest Area in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="CO2 Emissions from Agriculture (Mt CO2e)", side="left", showgrid=False),
    yaxis2=dict(title="Forest Area (sq. km)", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-7051999014884473603' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Install required libraries
# %pip install wbdata
# %pip install plotly

import wbdata
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import warnings

warnings.filterwarnings("ignore", message="Key .* not in persistent cache")

pd.options.plotting.backend = 'plotly'
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Define indicators for forest area and GDP
indicators = {
    "AG.LND.FRST.K2": "Forest Area (sq. km)",
    "NY.GDP.MKTP.CD": "GDP (current US$)"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API (without convert_date)
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add GDP trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["GDP (current US$)"], 
                         mode="lines", name="GDP (USD)", 
                         yaxis="y1"))

# Add Forest Area trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Forest Area (sq. km)"], 
                         mode="lines", name="Forest Area (sq. km)", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="GDP and Forest Area in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="GDP (USD)", side="left", showgrid=False),
    yaxis2=dict(title="Forest Area (sq. km)", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-8138669707646330719' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for forest area and GDP
indicators = {
    "AG.LND.FRST.K2": "Forest Area (sq. km)",
    "NY.GDP.MKTP.CD": "GDP (current US$)"
}

# Define country
country = "PER"  # Peru's country code

# Fetch data from World Bank API (without convert_date)
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add GDP trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["GDP (current US$)"], 
                         mode="lines", name="GDP (USD)", 
                         yaxis="y1"))

# Add Forest Area trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Forest Area (sq. km)"], 
                         mode="lines", name="Forest Area (sq. km)", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="GDP and Forest Area in Peru Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="GDP (USD)", side="left", showgrid=False),
    yaxis2=dict(title="Forest Area (sq. km)", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '985198873458968821' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7373424953007127767' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for forest area and GDP
indicators = {
    "AG.LND.FRST.K2": "Forest Area (sq. km)",
    "NY.GDP.MKTP.CD": "GDP (current US$)"
}

# Define country
country = "ECU"  # Ecuador's country code

# Fetch data from World Bank API (without convert_date)
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add GDP trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["GDP (current US$)"], 
                         mode="lines", name="GDP (USD)", 
                         yaxis="y1"))

# Add Forest Area trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Forest Area (sq. km)"], 
                         mode="lines", name="Forest Area (sq. km)", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="GDP and Forest Area in Ecuador Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="GDP (USD)", side="left", showgrid=False),
    yaxis2=dict(title="Forest Area (sq. km)", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '4729976388205604340' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5987918836576989296' not in persistent cache.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Define indicators for forest area and GDP
indicators = {
    "AG.LND.FRST.K2": "Forest Area (sq. km)",
    "NY.GDP.MKTP.CD": "GDP (current US$)"
}

# Define country
country = "BOL"  # Bolivia's country code

# Fetch data from World Bank API (without convert_date)
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add GDP trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["GDP (current US$)"], 
                         mode="lines", name="GDP (USD)", 
                         yaxis="y1"))

# Add Forest Area trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Forest Area (sq. km)"], 
                         mode="lines", name="Forest Area (sq. km)", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="GDP and Forest Area in Bolivia Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="GDP (USD)", side="left", showgrid=False),
    yaxis2=dict(title="Forest Area (sq. km)", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-4644607474705931669' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4057207728586361000' not in persistent cache.

# %%
# Define indicators for Food Production Index and Population
indicators = {
    "AG.PRD.FOOD.XD": "Food Production Index",
    "SP.POP.TOTL": "Population"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add Food Production Index trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Food Production Index"], 
                         mode="lines", name="Food Production Index", 
                         yaxis="y1"))

# Add Population trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Population"], 
                         mode="lines", name="Population", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Food Production Index and Population in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Food Production Index", side="left", showgrid=False),
    yaxis2=dict(title="Population", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '6605168156595893971' not in persistent cache.

# %%
# Define indicators for Agricultural Raw Materials Exports and Forest Area
indicators = {
    "TX.VAL.AGRI.ZS.UN": "Agricultural Exports (% of Merchandise Exports)",
    "AG.LND.FRST.K2": "Forest Area (sq. km)"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add Agricultural Exports trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Agricultural Exports (% of Merchandise Exports)"], 
                         mode="lines", name="Agricultural Exports (%)", 
                         yaxis="y1"))

# Add Forest Area trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Forest Area (sq. km)"], 
                         mode="lines", name="Forest Area (sq. km)", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Agricultural Exports and Forest Area in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Agricultural Exports (% of Merchandise Exports)", side="left", showgrid=False),
    yaxis2=dict(title="Forest Area (sq. km)", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-5028169619344729783' not in persistent cache.

# %%
# Define indicators for Forest Area and Agricultural Land
indicators = {
    "AG.LND.FRST.K2": "Forest Area (sq. km)",
    "AG.LND.AGRI.K2": "Agricultural Land (sq. km)"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add Forest Area trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Forest Area (sq. km)"], 
                         mode="lines", name="Forest Area (sq. km)", 
                         yaxis="y1"))

# Add Agricultural Land trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Agricultural Land (sq. km)"], 
                         mode="lines", name="Agricultural Land (sq. km)", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Forest Area vs Agricultural Land in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Forest Area (sq. km)", side="left", showgrid=False),
    yaxis2=dict(title="Agricultural Land (sq. km)", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-2471033914796019643' not in persistent cache.

# %%
# Define indicators for Forest Area and Agricultural Land
indicators = {
    "AG.LND.FRST.K2": "Forest Area (sq. km)",
    "AG.LND.AGRI.K2": "Agricultural Land (sq. km)"
}

# Define country
country = "BRA"  # Brazil's country code

# Fetch data from World Bank API
data = wbdata.get_dataframe(indicators, country=country)

# Convert index (years) to datetime format
data.index = pd.to_datetime(data.index.astype(str) + "-01-01")

# Drop missing values
data.dropna(inplace=True)

# Create figure
fig = go.Figure()

# Add Forest Area trace (left y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Forest Area (sq. km)"], 
                         mode="lines", name="Forest Area (sq. km)", 
                         yaxis="y1"))

# Add Agricultural Land trace (right y-axis)
fig.add_trace(go.Scatter(x=data.index, y=data["Agricultural Land (sq. km)"], 
                         mode="lines", name="Agricultural Land (sq. km)", 
                         yaxis="y2"))

# Update layout for dual axes
fig.update_layout(
    title="Forest Area vs Agricultural Land in Brazil Over Time",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Forest Area (sq. km)", side="left", showgrid=False),
    yaxis2=dict(title="Agricultural Land (sq. km)", side="right", overlaying="y", showgrid=False),
    legend=dict(x=0.1, y=1.1)
)

# Show plot
fig.show()
